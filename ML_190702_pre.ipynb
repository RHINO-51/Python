# %%
import numpy as np 
import pandas as pd
import matplotlib.pylab as plt

# %%
url = 'file:///C:/Users/wtime/Desktop/엠아이텍%20179290%20일자별%20시세%20-%20매일경제%20증권센터.html'
tables = pd.read_html(url, index_col=0,header=0)
df = tables[0]
df_final = df.iloc[22:-17,:1].astype(np.int)
val = df.iloc[22:-17,6:7].astype(np.int)
df_final.plot()
val.plot()

# %%
df = df.astype(np.int),df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 19/07/02 to 19/04/30
# Data columns (total 1 columns):
# 종가    40 non-null int32
# dtypes: int32(1)
# memory usage: 480.0+ bytes
