# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
df
# Out:
# [                                       Olympic Games
#  0                                        Main topics
#  1  Bids Boycotts Ceremonies Charter Host cities I...
#  2                                              Games
#  3  Summer Winter Summer Paralympic Winter Paralym...
#  4                                                vte,
#                                 Unnamed: 0_level_0 Summer Games  \
#                                    Team (IOC code)            №
#  0                               Afghanistan (AFG)           14
#  1                                   Algeria (ALG)           13
#  2                                 Argentina (ARG)           24
#  3                                   Armenia (ARM)            6
#  4                         Australasia (ANZ) [ANZ]            2
#  5                       Australia (AUS) [AUS] [Z]           26
#  6                                   Austria (AUT)           27
#  7                                Azerbaijan (AZE)            6
# ...

# %%
len(df) #리스트 안에 요소 16개
# Out:
# 16

# %%
data = df[1]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# MultiIndex(levels=[['Combined Total', 'Summer Games', 'Unnamed: 0_level_0', 'Winter Games'], ['Team (IOC code)', 'Total', 'Unnamed: 12_level_1', 'Unnamed: 13_level_1', 'Unnamed: 14_level_1', 'Unnamed: 2_level_1', 'Unnamed: 3_level_1', 'Unnamed: 4_level_1', 'Unnamed: 7_level_1', 'Unnamed: 8_level_1', 'Unnamed: 9_level_1', '№']],
#            codes=[[2, 1, 1, 1, 1, 1, 3, 3, 3, 3, 3, 0, 0, 0, 0, 0], [0, 11, 5, 6, 7, 1, 11, 8, 9, 10, 1, 11, 2, 3, 4, 1]])

# %%
data.index #가장 좌측의 데이터
# Out:
# RangeIndex(start=0, stop=153, step=1)

# %%
data.head()
# Out:
#         Unnamed: 0_level_0 Summer Games                                        \
#            Team (IOC code)            № Unnamed: 2_level_1 Unnamed: 3_level_1
# 0        Afghanistan (AFG)           14                  0                  0
# 1            Algeria (ALG)           13                  5                  4
# 2          Argentina (ARG)           24                 21                 25
# 3            Armenia (ARM)            6                  2                  6
# 4  Australasia (ANZ) [ANZ]            2                  3                  4
#
#                            Winter Games                                        \
#   Unnamed: 4_level_1 Total            № Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                  2     2            0                  0                  0
# 1                  8    17            3                  0                  0
# 2                 28    74           19                  0                  0
# ...

# %%
data.values # 데이터의 값들
# Out:
# array([['Afghanistan\xa0(AFG)', 14, 0, ..., 0, 2, 2],
#        ['Algeria\xa0(ALG)', 13, 5, ..., 4, 8, 17],
#        ['Argentina\xa0(ARG)', 24, 21, ..., 25, 28, 74],
#        ...,
#        ['Olympic Athletes from Russia\xa0(OAR) [OAR]', 0, 0, ..., 6, 9,
#         17],
#        ['Mixed team\xa0(ZZX) [ZZX]', 3, 8, ..., 5, 4, 17],
#        ['Totals', 28, 5115, ..., 6139, 6537, 18853]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 16 columns):
# (Unnamed: 0_level_0, Team (IOC code))    153 non-null object
# (Summer Games, №)                        153 non-null int64
# (Summer Games, Unnamed: 2_level_1)       153 non-null int64
# (Summer Games, Unnamed: 3_level_1)       153 non-null int64
# (Summer Games, Unnamed: 4_level_1)       153 non-null int64
# (Summer Games, Total)                    153 non-null int64
# (Winter Games, №)                        153 non-null int64
# (Winter Games, Unnamed: 7_level_1)       153 non-null int64
# (Winter Games, Unnamed: 8_level_1)       153 non-null int64
# (Winter Games, Unnamed: 9_level_1)       153 non-null int64
# (Winter Games, Total)                    153 non-null int64
# (Combined Total, №)                      153 non-null int64
# (Combined Total, Unnamed: 12_level_1)    153 non-null int64
# (Combined Total, Unnamed: 13_level_1)    153 non-null int64
# ...

# %%
data.describe() #기술하다. 통계치 구하기(수치 데이터 컬럼만)
# Out:
#       Summer Games                                                           \
#                  № Unnamed: 2_level_1 Unnamed: 3_level_1 Unnamed: 4_level_1
# count   153.000000         153.000000         153.000000         153.000000
# mean     14.045752          66.862745          66.418301          71.725490
# std       7.328154         422.599849         416.404023         447.853436
# min       0.000000           0.000000           0.000000           0.000000
# 25%       9.000000           0.000000           1.000000           1.000000
# 50%      14.000000           3.000000           4.000000           6.000000
# 75%      19.000000          26.000000          30.000000          31.000000
# max      28.000000        5115.000000        5081.000000        5487.000000
#
#                     Winter Games                                        \
#               Total            № Unnamed: 7_level_1 Unnamed: 8_level_1
# ...

# %%
data.head()
# Out:
#         Unnamed: 0_level_0 Summer Games                                        \
#            Team (IOC code)            № Unnamed: 2_level_1 Unnamed: 3_level_1
# 0        Afghanistan (AFG)           14                  0                  0
# 1            Algeria (ALG)           13                  5                  4
# 2          Argentina (ARG)           24                 21                 25
# 3            Armenia (ARM)            6                  2                  6
# 4  Australasia (ANZ) [ANZ]            2                  3                  4
#
#                            Winter Games                                        \
#   Unnamed: 4_level_1 Total            № Unnamed: 7_level_1 Unnamed: 8_level_1
# 0                  2     2            0                  0                  0
# 1                  8    17            3                  0                  0
# 2                 28    74           19                  0                  0
# ...

# %%
data.head()
summer = data.iloc[:,:6]
summer.head(2)
# Out:
#   Unnamed: 0_level_0 Summer Games                                        \
#      Team (IOC code)            № Unnamed: 2_level_1 Unnamed: 3_level_1
# 0  Afghanistan (AFG)           14                  0                  0
# 1      Algeria (ALG)           13                  5                  4
#
#
#   Unnamed: 4_level_1 Total
# 0                  2     2
# 1                  8    17

# %%
summer.columns =['나라','경기수', '금','은', '동', '계']
summer.head()
# Out:
#                         나라  경기수   금   은   동   계
# 0        Afghanistan (AFG)   14   0   0   2   2
# 1            Algeria (ALG)   13   5   4   8  17
# 2          Argentina (ARG)   24  21  25  28  74
# 3            Armenia (ARM)    6   2   6   6  14
# 4  Australasia (ANZ) [ANZ]    2   3   4   5  12

# %%
summer_sort = summer.sort_values('금',ascending=False)

# %%
summer_sort.to_excel('하계올림픽메달.xlsx')

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/All-time_table_of_the_FIFA_World_Cup', index_col=0, header=0)

# %%
len(df)
# Out:
# 4

# %%
for i in range(len(df)):
    data =df[i]
    print(data.shape)
# Out:
# (81, 18)
# (14, 18)
# (13, 1)
# (8, 1)

# %%
worldcup =df[0]
worldcup.head()
# Out:
#          Team  App's App's.1  Overall records Overall records.1  \
# №
# №        Team  App's   App's  Overall records   Overall records
# №        Team      T       S                P                 W
# 1      Brazil     21     +21              109                73
# 2  Germany[A]     19     +17              109                67
# 3       Italy     18      −1               83                45
#
#   Overall records.2 Overall records.3 Overall records.4 Overall records.5  \
# №
# №   Overall records   Overall records   Overall records   Overall records
# №                 D                 L                 F                 A
# 1                18                18               229               105
# 2                20                22               226               125
# 3                21                17               128                77
#
#   Overall records.6   Points Points.1 Points.2 Points.3 Points.4 Points.5  \
# №
# ...

# %%
#와이즈리포트 추천종목
url = 'https://finance.naver.com/'
df = pd.read_html(url, encoding='cp949', header=0, index_col=0)# header : 컬럼 이름 위치

# %%
len(df)
# Out:
# 12

# %%
wise = df[0]

# %%
wise_save = wise.iloc[1:,1::2]# 1번째 컬럼부터 2칸씩 떨어져서

# %%
wise_save.to_excel('naver_wise.xlsx')

# %% [markdown]
# #pandas 란 panal datas 데이터 분석용 라이브러리
# #value를 numpy 로 관리
# #컬럼 -> 시리즈, 표 -> 데이터 프레임

# %%
index = pd.date_range('1/1/2000',periods=8)

# %%
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
#dataframe 구성요소(values, index, columns)
df = pd.DataFrame(data = np.random.rand(8,3), index=index, columns=list('abc'))

# %%
df.head(2)
# Out:
#                    a         b         c
# 2000-01-01  0.938181  0.154963  0.391246
# 2000-01-02  0.465658  0.514261  0.872982

# %%
#Boolean Mask 0.5보다 큰 값만 뽑기 x[x>0.5], [df > 0.5] 는 마스크 바로 인덱스에 넣으면 된다. 
a= df['a']
a[a > 0.5]
# Out:
# 2000-01-01    0.938181
# 2000-01-04    0.958772
# 2000-01-07    0.509819
# Name: a, dtype: float64

# %%
df.T #transpose
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# a    0.938181    0.465658    0.232867    0.958772    0.133067    0.486157
# b    0.154963    0.514261    0.881134    0.753899    0.705157    0.201773
# c    0.391246    0.872982    0.540895    0.665487    0.730784    0.126263
#
#    2000-01-07  2000-01-08
# a    0.509819    0.476169
# b    0.399828    0.634531
# c    0.716730    0.172118

# %%
a= df['a']
b = df['b']

# %%
a_b_mean = (a+b)/2

# %%
 # dictionary 에 새로운 키 추가하기
df['ab_mean'] = a_b_mean

# %%
df
# Out:
#                    a         b         c   ab_mean
# 2000-01-01  0.938181  0.154963  0.391246  0.546572
# 2000-01-02  0.465658  0.514261  0.872982  0.489960
# 2000-01-03  0.232867  0.881134  0.540895  0.557000
# 2000-01-04  0.958772  0.753899  0.665487  0.856336
# 2000-01-05  0.133067  0.705157  0.730784  0.419112
# 2000-01-06  0.486157  0.201773  0.126263  0.343965
# 2000-01-07  0.509819  0.399828  0.716730  0.454823
# 2000-01-08  0.476169  0.634531  0.172118  0.555350

# %%
df = pd.read_csv('age.csv', index_col=0)

# %%
df.shape
# Out:
# (967, 103)

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 966 entries, 서울특별시  (1100000000) to 인천광역시 강화군 (2871000000)
# Columns: 103 entries, 2019년02월_계_총인구수 to 2019년02월_계_100세 이상
# dtypes: float64(1), object(102)
# memory usage: 784.9+ KB

# %%
df = df.dropna() #누락 행 제거

# %%
df = df.replace(',','',regex=True)

# %%
a = df.astype('int')

a.head()
b= a.div(a['2019년02월_계_총인구수'],axis=0)
b
del b['2019년02월_계_총인구수'], b['2019년02월_계_연령구간인구수']

# %%
name = input('원하는 지역의 이름을 입력해주세요 : ')
c = b.index.str.contains(name)
df2 = b[c]
df2
# Out:
# 원하는 지역의 이름을 입력해주세요 : 신도림동
#                             2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.008747       0.008962       0.010894
#
#                             2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.011082       0.010438       0.010948
#
#                             2019년02월_계_6세  2019년02월_계_7세  2019년02월_계_8세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)       0.011189       0.011645       0.011028
#
#                             2019년02월_계_9세  ...  2019년02월_계_91세  \
# 행정구역                                       ...
# 서울특별시 구로구 신도림동(1153051000)       0.010384  ...        0.000402
#
#                             2019년02월_계_92세  2019년02월_계_93세  2019년02월_계_94세  \
# 행정구역
# 서울특별시 구로구 신도림동(1153051000)        0.000349        0.000322        0.000134
#
#                             2019년02월_계_95세  2019년02월_계_96세  2019년02월_계_97세  \
# 행정구역
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
df2.T.plot()
plt.show()

# %%
import numpy as np 
x = df2.sub
